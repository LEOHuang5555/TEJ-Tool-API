# %%
import tejapi 
tejapi.ApiConfig.api_base="http://10.10.10.66"
tejapi.ApiConfig.api_key = "3jUCETU2KiPwGJeyETYOQd1TCoDoxX"
tejapi.ApiConfig.ignoretz = True
from TejToolAPI import *
import numpy as np
import dask.dataframe as dd
import dask

# %% [markdown]
# ## 財務資料
# ### ticker
# - 單一股票
# - 多股
# ### columns
# - 欄位 not within table 時的錯誤訊息
# ### transfer_chinese_columns
#     預設 transfer_chinese_columns = False
# - 測試欄位轉換成中文(transfer_chinese_columns = True)
# ### fin_type = [A, Q, TTM]
#     A: 表示累積
#     Q: 表示單季
#     TTM: 表示移動4季
# ### include_self_acc
# - 投資用財務包含自結和董事會決議數(include_self_acc = 'Y')
# - 僅投資用財務(include_self_acc = 'N')

# %%
ticker = ['2881', '2330','2882']
columns =['r404','r401', 'eps', 'Sales_Per_Employee']
data = get_history_data(ticker=ticker, columns=columns, transfer_to_chinese=False)
data
# Out:
#      coid      mdate  Sales_Growth_Rate_A curr  Pre_Tax_Income_Growth_Rate_A  \
# 0    2882 2013-01-03                  NaN  NaN                           NaN
# 1    2882 2013-01-15                  NaN  NaN                           NaN
# 2    2882 2013-01-22                  NaN  NaN                           NaN
# 3    2882 2013-01-24                  NaN  NaN                           NaN
# 4    2882 2013-01-25                  NaN  NaN                           NaN
# ..    ...        ...                  ...  ...                           ...
# 682  2882 2020-07-23                32.18  TWD                         16.51
# 683  2882 2020-07-27                32.18  TWD                         16.51
# 684  2882 2020-07-30                32.18  TWD                         16.51
# 685  2882 2020-08-10                32.18  TWD                         -5.65
# 686  2882 2020-09-01                32.26  TWD                         -4.82
#
#     fin_ind  Basic_Earnings_Per_Share_A  Sales_Growth_Rate_Q  \
# 0       NaN                         NaN                  NaN
# 1       NaN                         NaN                  NaN
# 2       NaN                         NaN                  NaN
# 3       NaN                         NaN                  NaN
# 4       NaN                         NaN                  NaN
# ..      ...                         ...                  ...
# 682       O                        2.68                34.59
# 683       O                        2.68                34.59
# 684       O                        2.68                34.59
# 685       O                        2.15                34.59
# 686       O                        2.18                34.76
#
#      Pre_Tax_Income_Growth_Rate_Q  Basic_Earnings_Per_Share_Q  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ..                            ...                         ...
# 682                        -16.97                       -0.23
# 683                        -16.97                       -0.23
# 684                        -16.97                       -0.23
# 685                        -53.55                       -0.23
# 686                        -52.17                        0.67
#
#      Sales_Growth_Rate_TTM  Pre_Tax_Income_Growth_Rate_TTM  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
# ..                     ...                             ...
# 682                  37.50                           33.46
# 683                  37.50                           33.46
# 684                  37.50                           33.46
# 685                  37.50                           18.22
# 686                  37.54                           18.79
#
#      Basic_Earnings_Per_Share_TTM  Sales_Per_Employee_A  Sales_Per_Employee_Q  \
# 0                             NaN               6093.66                623.64
# 1                             NaN               6093.66                623.64
# 2                             NaN               6093.66                623.64
# 3                             NaN               6093.66                623.64
# 4                             NaN               6093.66                623.64
# ..                            ...                   ...                   ...
# 682                           NaN               2870.20               2870.20
# 683                           NaN               2870.20               2870.20
# 684                           NaN               2870.20               2870.20
# 685                           NaN               2870.20               2870.20
# 686                          4.67               5636.59               2791.68
#
#      Sales_Per_Employee_TTM
# 0                   6093.66
# 1                   6093.66
# 2                   6093.66
# 3                   6093.66
# 4                   6093.66
# ..                      ...
# 682                10498.51
# 683                10498.51
# 684                10498.51
# 685                10498.51
# 686                11131.39
#
# [8383 rows x 16 columns]

# %%
ticker = ['2881', '1101','9958','2330']
columns = ['r404','r401']
data = get_history_data(ticker=ticker, columns=columns)
data
# Out:
#       coid      mdate  Sales_Growth_Rate_A curr  Pre_Tax_Income_Growth_Rate_A  \
# 0     2881 2013-01-31                  NaN  NaN                           NaN
# 1     2881 2013-03-07                  NaN  NaN                           NaN
# 2     2881 2013-03-14                  NaN  NaN                           NaN
# 3     2881 2013-03-19                  NaN  NaN                           NaN
# 4     2881 2013-03-20                  NaN  NaN                           NaN
# ...    ...        ...                  ...  ...                           ...
# 1044  2330 2022-10-04                39.57  TWD                         61.87
# 1045  2330 2022-11-07                42.56  TWD                         69.25
# 1046  2330 2022-11-18                42.56  TWD                         69.25
# 1047  2330 2023-02-20                42.61  TWD                         72.54
# 1048  2330 2023-03-27                42.61  TWD                         72.54
#
#      fin_ind  Sales_Growth_Rate_Q  Pre_Tax_Income_Growth_Rate_Q  \
# 0        NaN                  NaN                           NaN
# 1        NaN                  NaN                           NaN
# 2        NaN                  NaN                           NaN
# 3        NaN                  NaN                           NaN
# 4        NaN                  NaN                           NaN
# ...      ...                  ...                           ...
# 1044       F                43.53                         78.06
# 1045       F                47.86                         82.16
# 1046       F                47.86                         82.16
# 1047       F                42.75                         81.08
# 1048       F                42.75                         81.08
#
#       Sales_Growth_Rate_TTM  Pre_Tax_Income_Growth_Rate_TTM
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
# ...                     ...                             ...
# 1044                  29.30                           37.19
# 1045                  37.45                           55.51
# 1046                  37.45                           55.51
# 1047                  42.61                           72.54
# 1048                  42.61                           72.54
#
# [12609 rows x 10 columns]

# %%
ticker = ['2881', '1101','9958','2330']
columns = ['r404','r401']
data = get_history_data(ticker=ticker, columns=columns,transfer_to_chinese=True)
data
# Out:
#       股票代碼         日期  營收成長率_A   幣別  稅前淨利成長率_A  產業別  營收成長率_Q  稅前淨利成長率_Q  \
# 0     9958 2013-01-17      NaN  NaN        NaN  NaN      NaN        NaN
# 1     9958 2013-02-01      NaN  NaN        NaN  NaN      NaN        NaN
# 2     9958 2013-03-15      NaN  NaN        NaN  NaN      NaN        NaN
# 3     9958 2013-05-10    27.72  TWD     482.50    F      NaN        NaN
# 4     9958 2013-05-15    27.72  TWD     482.50    F      NaN        NaN
# ...    ...        ...      ...  ...        ...  ...      ...        ...
# 1044  9958 2023-03-13   -13.79  TWD     -62.12    F   -31.06     -69.19
# 1045  9958 2023-03-15    -7.18  TWD     -91.34    F    10.97    -329.35
# 1046  9958 2023-03-20    -7.18  TWD     -91.34    F    10.97    -329.35
# 1047  9958 2023-03-22    -7.18  TWD     -91.34    F    10.97    -329.35
# 1048  9958 2023-03-24    -7.18  TWD     -91.34    F    10.97    -329.35
#
#       營收成長率_TTM  稅前淨利成長率_TTM
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3        100.67       519.74
# 4        100.67       519.74
# ...         ...          ...
# 1044       5.25       -53.24
# 1045      -7.18       -91.34
# 1046      -7.18       -91.34
# 1047      -7.18       -91.34
# 1048      -7.18       -91.34
#
# [12609 rows x 10 columns]

# %%
ticker = ['2881', '1101','9958','2330']
columns = ['r404','r401','eps']
fin_type = ['A','Q']
data = get_history_data(ticker=ticker, columns=columns,transfer_to_chinese=True, fin_type=fin_type)
data
# Out:
#       股票代碼         日期  營收成長率_A   幣別  稅前淨利成長率_A  產業別  母公司每股盈餘_A  營收成長率_Q  \
# 0     1101 2013-01-14      NaN  NaN        NaN  NaN        NaN      NaN
# 1     1101 2013-01-15      NaN  NaN        NaN  NaN        NaN      NaN
# 2     1101 2013-01-23      NaN  NaN        NaN  NaN        NaN      NaN
# 3     1101 2013-02-06      NaN  NaN        NaN  NaN        NaN      NaN
# 4     1101 2013-02-26      NaN  NaN        NaN  NaN        NaN      NaN
# ...    ...        ...      ...  ...        ...  ...        ...      ...
# 1044  1101 2023-01-30     3.08  TWD     -85.32    F       0.38    15.78
# 1045  1101 2023-03-10     6.44  TWD     -74.51    F       0.74    14.99
# 1046  1101 2023-03-17     6.44  TWD     -74.51    F       0.74    14.99
# 1047  1101 2023-03-27     6.44  TWD     -74.51    F       0.74    14.99
# 1048  1101 2023-04-14     6.44  TWD     -74.51    F       0.74    14.99
#
#       稅前淨利成長率_Q  母公司每股盈餘_Q  營收成長率_TTM  稅前淨利成長率_TTM  母公司每股盈餘_TTM
# 0           NaN        NaN        NaN          NaN          NaN
# 1           NaN        NaN        NaN          NaN          NaN
# 2           NaN        NaN        NaN          NaN          NaN
# 3           NaN        NaN        NaN          NaN          NaN
# 4           NaN        NaN        NaN          NaN          NaN
# ...         ...        ...        ...          ...          ...
# 1044     -55.17       0.22       0.36       -66.39         1.24
# 1045     -43.48       0.36       6.44       -74.51         0.79
# 1046     -43.48       0.36       6.44       -74.51         0.79
# 1047     -43.48       0.36       6.44       -74.51         0.79
# 1048     -43.48       0.36       6.44       -74.51         0.79
#
# [12609 rows x 13 columns]

# %%
ticker = ['2881', '1101','9958','2330']
columns = ['r404','r401','eps']
fin_type = ['A','Q']
data = get_history_data(ticker=ticker, columns=columns,transfer_to_chinese=True, fin_type=fin_type, include_self_acc='N')
data
# Out:
#       股票代碼         日期  營收成長率_A   幣別  稅前淨利成長率_A  產業別  母公司每股盈餘_A  營收成長率_Q  \
# 0     1101 2013-01-14      NaN  NaN        NaN  NaN        NaN      NaN
# 1     1101 2013-01-15      NaN  NaN        NaN  NaN        NaN      NaN
# 2     1101 2013-01-23      NaN  NaN        NaN  NaN        NaN      NaN
# 3     1101 2013-02-06      NaN  NaN        NaN  NaN        NaN      NaN
# 4     1101 2013-02-26      NaN  NaN        NaN  NaN        NaN      NaN
# ...    ...        ...      ...  ...        ...  ...        ...      ...
# 1044  2881 2023-02-24      NaN  NaN        NaN  NaN        NaN      NaN
# 1045  2881 2023-03-07      NaN  NaN        NaN  NaN        NaN      NaN
# 1046  2881 2023-04-10   -46.64  TWD     -63.38    O       3.54  -129.64
# 1047  2881 2023-04-13   -46.64  TWD     -63.38    O       3.54  -129.64
# 1048  2881 2023-04-18   -46.64  TWD     -63.38    O       3.54  -129.64
#
#       稅前淨利成長率_Q  母公司每股盈餘_Q  營收成長率_TTM  稅前淨利成長率_TTM  母公司每股盈餘_TTM
# 0           NaN        NaN        NaN          NaN          NaN
# 1           NaN        NaN        NaN          NaN          NaN
# 2           NaN        NaN        NaN          NaN          NaN
# 3           NaN        NaN        NaN          NaN          NaN
# 4           NaN        NaN        NaN          NaN          NaN
# ...         ...        ...        ...          ...          ...
# 1044        NaN        NaN        NaN          NaN          NaN
# 1045        NaN        NaN        NaN          NaN          NaN
# 1046    -381.96      -2.97     -46.64       -63.38         3.79
# 1047    -381.96      -2.97     -46.64       -63.38         3.79
# 1048    -381.96      -2.97     -46.64       -63.38         3.79
#
# [12609 rows x 13 columns]

# %%
ticker = ['2881', '1101','9958','2330']
columns = ['r404','r401','eps']
fin_type = ['A','Q']
data = get_history_data(ticker=ticker, columns=columns,transfer_to_chinese=True, fin_type=fin_type, include_self_acc='Y')
data
# Out:
#       股票代碼         日期  營收成長率_A   幣別  稅前淨利成長率_A  產業別  母公司每股盈餘_A  營收成長率_Q  \
# 0     1101 2013-01-14      NaN  NaN        NaN  NaN        NaN      NaN
# 1     1101 2013-01-15      NaN  NaN        NaN  NaN        NaN      NaN
# 2     1101 2013-01-23      NaN  NaN        NaN  NaN        NaN      NaN
# 3     1101 2013-02-06      NaN  NaN        NaN  NaN        NaN      NaN
# 4     1101 2013-02-26      NaN  NaN        NaN  NaN        NaN      NaN
# ...    ...        ...      ...  ...        ...  ...        ...      ...
# 1044  2881 2019-08-02    -6.55  TWD     -13.40    O       2.70   -11.93
# 1045  2881 2019-08-16    -6.55  TWD     -13.40    O       2.70   -11.93
# 1046  2881 2019-08-23    -6.55  TWD     -13.40    O       2.70   -11.93
# 1047  2881 2019-10-08     3.97  TWD       2.91    O       4.98    22.32
# 1048  2881 2019-10-14     3.97  TWD       2.92    O       4.98    22.32
#
#       稅前淨利成長率_Q  母公司每股盈餘_Q  營收成長率_TTM  稅前淨利成長率_TTM  母公司每股盈餘_TTM
# 0           NaN        NaN        NaN          NaN          NaN
# 1           NaN        NaN        NaN          NaN          NaN
# 2           NaN        NaN        NaN          NaN          NaN
# 3           NaN        NaN        NaN          NaN          NaN
# 4           NaN        NaN        NaN          NaN          NaN
# ...         ...        ...        ...          ...          ...
# 1044     -20.33       1.48      -1.85       -30.43         4.32
# 1045     -20.33       1.48      -1.85       -30.43         4.32
# 1046     -20.33       1.48      -1.85       -30.43         4.32
# 1047      31.14       2.53       1.64       -17.05         4.98
# 1048      31.16       2.53       1.64       -17.04         4.98
#
# [12609 rows x 13 columns]

# %% [markdown]
# ## 股價資料/籌碼/月營收/集保資料/交易日期表
# ### ticker
# - 單一股票
# - 多股
# ### columns
# - 欄位 not within table 時的錯誤訊息
# ### transfer_chinese_columns
# 預設 transfer_chinese_columns = False
# - 測試欄位轉換成中文(transfer_chinese_columns = True)

# %%
ticker = ['2881']
columns = ['開盤價','收盤價','產業別_中文','調整係數','shares']
data = get_history_data(ticker=ticker, columns=columns, transfer_to_chinese=True)
data
# Out:
#      股票代碼         日期      期末股數    開盤價    收盤價      調整係數         產業別_中文  \
# 0    2881 2013-11-15  10233604  41.00  40.85  0.567528  M2800 金融保險類指數
# 1    2881 2013-11-22  10233604  40.90  41.20  0.567528  M2800 金融保險類指數
# 2    2881 2014-03-14  10233604  41.40  41.35  0.567528  M2800 金融保險類指數
# 3    2881 2014-03-25  10233604  40.55  41.00  0.567528  M2800 金融保險類指數
# 4    2881 2014-05-14  10233604  39.45  40.05  0.567528  M2800 金融保險類指數
# ..    ...        ...       ...    ...    ...       ...            ...
# 216  2881 2023-02-24  12395213  59.70  60.00  1.000000  M2800 金融保險類指數
# 217  2881 2023-03-07  12395213  60.00  59.80  1.000000  M2800 金融保險類指數
# 218  2881 2023-04-10  12395213  56.90  57.10  1.000000  M2800 金融保險類指數
# 219  2881 2023-04-13  12395213  57.30  57.40  1.000000  M2800 金融保險類指數
# 220  2881 2023-04-18  12395213  58.60  58.60  1.000000  M2800 金融保險類指數
#
#           期末股數_A       期末股數_Q  期末股數_TTM
# 0    10233604.00  10233604.00       NaN
# 1    10233604.00  10233604.00       NaN
# 2    10233604.00  10233604.00       NaN
# 3    10233604.00  10233604.00       NaN
# 4    10233604.00  10233604.00       NaN
# ..           ...          ...       ...
# 216  12395212.61  12395212.61       NaN
# 217  12395212.61  12395212.61       NaN
# 218  12395212.61  12395212.61       NaN
# 219  12395212.61  12395212.61       NaN
# 220  12395212.61  12395212.61       NaN
#
# [2770 rows x 10 columns]

# %%
ticker = ['2881', '1101','9958']
columns = ['開盤價','收盤價']
data = get_history_data(ticker=ticker, columns=columns)
data
# Out:
#      coid      mdate  Close  Open
# 0    2881 2013-01-31  37.75  37.4
# 1    2881 2013-03-07  41.00  40.5
# 2    2881 2013-03-14  42.85  43.0
# 3    2881 2013-03-19  41.70  41.5
# 4    2881 2013-03-20  41.85  42.0
# ..    ...        ...    ...   ...
# 621  1101 2023-01-30  36.95  37.2
# 622  1101 2023-03-10  36.70  36.9
# 623  1101 2023-03-17  36.40  36.6
# 624  1101 2023-03-27  36.65  37.0
# 625  1101 2023-04-14  37.55  37.6
#
# [7566 rows x 4 columns]

# %%
ticker = ['2881', '1101','9958']
columns = ['開盤價','收盤價', 'roi', 'd0001', '外資買進金額_元','集保庫存股數_千股','是否為臺灣50成分股']
data = get_history_data(ticker=ticker, columns=columns, transfer_to_chinese=True)
data
# Out:
#      股票代碼         日期     報酬率    收盤價    開盤價  外資買進金額_元 是否為臺灣50成分股     單月營收_千元  \
# 0    2881 2015-08-31  2.9466  55.90  54.10    894680             47776689.0
# 1    2881 2015-09-18 -0.3617  55.10  54.50    401844             40839266.0
# 2    2881 2015-10-12  0.3839  52.30  52.50    642401             41734756.0
# 3    2881 2015-10-26  0.0000  53.90  54.20    339732             41734756.0
# 4    2881 2015-11-06 -2.6834  54.40  55.40    237946             41734756.0
# ..    ...        ...     ...    ...    ...       ...        ...         ...
# 621  9958 2017-11-28  1.1152  13.60  13.75      1074               152063.0
# 622  9958 2017-12-04 -3.2787  14.75  14.95        30               152063.0
# 623  9958 2017-12-18 -1.9886  17.25  17.75       207               158651.0
# 624  9958 2017-12-25  0.5277  19.05  19.00         0               158651.0
# 625  9958 2018-01-04  9.9609  28.15  26.90     34118               158651.0
#
#       集保庫存股數_千股
# 0    10233603.0
# 1    10233603.0
# 2    10233603.0
# 3    10233603.0
# 4    10233603.0
# ..          ...
# 621    185558.0
# 622    185558.0
# 623    185558.0
# 624    185558.0
# 625    185558.0
#
# [7604 rows x 9 columns]

# %% [markdown]
# ## ToolAPI_plus

# %%
import ToolAPI_plus

# %%
toolapi = ToolAPI_plus.ToolAPI()

# %%
toolapi.tickers = ['2330','2881','2404']
toolapi.fields = ['r401', 'r404','close_d']
toolapi.transfer_to_chinese = False

# %%
toolapi.search_columns(['r404'])

# %%
toolapi.transfer_chinese_columns(toolapi.fields)

# %%
toolapi.get_history_data()

# %%
ticker = ['2881']
columns = ['stktp_c','stktp_e', 'ri']
data = get_history_data(ticker=ticker, columns=columns)
data
# Out:
#       coid      mdate security_type_eng security_type  Recurring_Net_Income_A  \
# 0     2881 2013-01-02      Common Stock           普通股                     NaN
# 1     2881 2013-01-03      Common Stock           普通股                     NaN
# 2     2881 2013-01-04      Common Stock           普通股                     NaN
# 3     2881 2013-01-07      Common Stock           普通股                     NaN
# 4     2881 2013-01-08      Common Stock           普通股                     NaN
# ...    ...        ...               ...           ...                     ...
# 2764  2881 2023-04-20      Common Stock           普通股              47864492.0
# 2765  2881 2023-04-21      Common Stock           普通股              47864492.0
# 2766  2881 2023-04-24      Common Stock           普通股              47864492.0
# 2767  2881 2023-04-25      Common Stock           普通股              47864492.0
# 2768  2881 2023-04-26      Common Stock           普通股              47864492.0
#
#       Recurring_Net_Income_Q  Recurring_Net_Income_TTM
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 2764             -37141758.0                47864492.0
# 2765             -37141758.0                47864492.0
# 2766             -37141758.0                47864492.0
# 2767             -37141758.0                47864492.0
# 2768             -37141758.0                47864492.0
#
# [2769 rows x 7 columns]

# %% [markdown]
# ## 取得全樣本之股票代碼

# %%
import sqlalchemy as sql

# %%
# connect to NDB(GLOBAL)
host='172.16.20.232' # 172.16.20.231
port='5432'
database = 'twn'
username = '2022011702' 
password = "[password]:'Z5799041a'" 
ndb_twn = sql.create_engine('postgresql://'+username+':'+password+'@'+host+':'+port+'/'+database)
twn_conn = ndb_twn.connect()
print("Connection established")
# Out:
# Connection established

# %%
scripts = sql.text("select distinct stk_id from prc.stock_prc where zdate > '2008-01-01' and mkt = 'TWSE'")#
result = pd.read_sql(scripts, twn_conn)
twn_conn.close()

# %%
result
# Out:
#          stk_id
# 0        064161
# 1       058082X
# 2       034309Y
# 3       086546Z
# 4       079109Z
# ...         ...
# 319643  036444Y
# 319644  07516PU
# 319645  037426W
# 319646  065909Z
# 319647  072146Y
#
# [319648 rows x 1 columns]

# %% [markdown]
# ## 檢查 DataFrame data type

# %%
ticker = ['2330']
all_columns = para.table_columns['COLUMNS'].tolist()
columns = ['Sales_Per_Share', 'Sales_Per_Employee', 'r401']
data = get_history_data(ticker=ticker, columns=all_columns, transfer_to_chinese=False, npartitions = 1)
data
# Out:
#       coid      mdate  High_Low_Diff  Dividend_Yield_TWSE  \
# 0     2330 2013-01-02         2.8866                 3.01
# 1     2330 2013-01-03         2.0080                 2.97
# 2     2330 2013-01-04         1.4851                 2.96
# 3     2330 2013-01-07         1.8719                 2.99
# 4     2330 2013-01-08         1.0945                 3.01
# ...    ...        ...            ...                  ...
# 2809  2330 2023-04-20         1.1765                 2.14
# 2810  2330 2023-04-21         1.9493                 2.15
# 2811  2330 2023-04-24         1.1742                 2.17
# 2812  2330 2023-04-25         1.3807                 2.21
# 2813  2330 2023-04-26         1.5060                 2.24
#
#       Cash_Dividend_Yield_TEJ  Trade_Value_Percentage  Volume_1000_Shares  \
# 0                      3.0100                   5.341               40647
# 1                      2.9700                   4.427               44335
# 2                      2.9500                   4.117               39502
# 3                      2.9800                   4.956               42328
# 4                      3.0100                   3.651               31218
# ...                       ...                     ...                 ...
# 2809                   2.1442                   4.822               21002
# 2810                   2.1526                   5.353               25440
# 2811                   2.1696                   5.303               17579
# 2812                   2.2088                   8.054               40916
# 2813                   2.2380                   7.998               33174
#
#       Market_Cap_Percentage   mkt  Close  ...  \
# 0                 12.022579  TWSE   99.6  ...
# 1                 12.101697  TWSE  101.0  ...
# 2                 12.209339  TWSE  101.5  ...
# 3                 12.168106  TWSE  100.5  ...
# 4                 12.123423  TWSE   99.7  ...
# ...                     ...   ...    ...  ...
# 2809              27.134452  TWSE  513.0  ...
# 2810              27.210256  TWSE  511.0  ...
# 2811              26.955999  TWSE  507.0  ...
# 2812              26.918336  TWSE  498.0  ...
# 2813              26.560034  TWSE  491.5  ...
#
#       Gain_or_Loss_on_Valuation_of_Assets_TTM  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 2809                                -622537.0
# 2810                                -622537.0
# 2811                                -622537.0
# 2812                                -622537.0
# 2813                                -622537.0
#
#       Depreciation_and_Amortisation_TTM  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2809                        437254273.0
# 2810                        437254273.0
# 2811                        437254273.0
# 2812                        437254273.0
# 2813                        437254273.0
#
#       Effect_of_Exchange_Rate_Changes_on_Cash_and_Cash_Equivalents_TTM  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2809                                         58396970.0
# 2810                                         58396970.0
# 2811                                         58396970.0
# 2812                                         58396970.0
# 2813                                         58396970.0
#
#       Other_Cash_Equivalents_Increase_Decrease_TTM  Sales_Per_Employee_TTM  \
# 0                                              NaN                     NaN
# 1                                              NaN                     NaN
# 2                                              NaN                     NaN
# 3                                              NaN                     NaN
# 4                                              NaN                     NaN
# ...                                            ...                     ...
# 2809                                           0.0                34747.84
# 2810                                           0.0                34747.84
# 2811                                           0.0                34747.84
# 2812                                           0.0                34747.84
# 2813                                           0.0                34747.84
#
#       Weighted_Average_Outstanding_Shares_Thousand_TTM  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 2809                                               NaN
# 2810                                               NaN
# 2811                                               NaN
# 2812                                               NaN
# 2813                                               NaN
#
#       Net_Income_Attributable_to_Non_controlling_Interest_TTM  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2809                                           370266.0
# 2810                                           370266.0
# 2811                                           370266.0
# 2812                                           370266.0
# 2813                                           370266.0
#
#       Impairment_Loss_on_Intangible_Assets_TTM  Debt/Equity_Ratio_TTM  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# ...                                        ...                    ...
# 2809                                       0.0                    NaN
# 2810                                       0.0                    NaN
# 2811                                       0.0                    NaN
# 2812                                       0.0                    NaN
# 2813                                       0.0                    NaN
#
#       Accounts_Payable_Turnover_TTM
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 2809                           16.2
# 2810                           16.2
# 2811                           16.2
# 2812                           16.2
# 2813                           16.2
#
# [2814 rows x 642 columns]

# %%
import dask.config
num_workers = dask.config.get('distributed.worker')
num_workers
# Out:
# {'blocked-handlers': [],
#  'multiprocessing-method': 'spawn',
#  'use-file-locking': True,
#  'transfer': {'message-bytes-limit': '50MB'},
#  'connections': {'outgoing': 50, 'incoming': 10},
#  'preload': [],
#  'preload-argv': [],
#  'daemon': True,
#  'validate': False,
#  'resources': {},
#  'lifetime': {'duration': None, 'stagger': '0 seconds', 'restart': False},
#  'profile': {'enabled': True,
#   'interval': '10ms',
#   'cycle': '1000ms',
#   'low-level': False},
#  'memory': {'recent-to-old-time': '30s',
#   'rebalance': {'measure': 'optimistic',
#    'sender-min': 0.3,
#    'recipient-max': 0.6,
#    'sender-recipient-gap': 0.1},
#   'transfer': 0.1,
#   'target': 0.6,
#   'spill': 0.7,
#   'pause': 0.8,
#   'terminate': 0.95,
#   'max-spill': False,
#   'monitor-interval': '100ms'},
#  'http': {'routes': ['distributed.http.worker.prometheus',
#    'distributed.http.health',
#    'distributed.http.statics']}}

# %%
# 建立一個DataFrame
df = pd.DataFrame({
        'key': ['A', 'B', 'C', 'A', 'B', 'C'],
        'date':['2020-01-01', '2020-01-01','2020-01-01','2020-01-02','2020-01-02','2020-01-02'],
        'value': [1, 2, None, 4, None, 6]
    })

# 以 'key' 欄位為基礎，做前值填補
df['value'] = df.groupby(['key'])['value'].fillna(method='ffill')

print(df.reset_index(drop=True))
# Out:
#   key        date  value
# 0   A  2020-01-01    1.0
# 1   B  2020-01-01    2.0
# 2   C  2020-01-01    NaN
# 3   A  2020-01-02    4.0
# 4   B  2020-01-02    2.0
# 5   C  2020-01-02    6.0

# %%
# 生成一個範例資料集
df = pd.DataFrame({
    'group': ['A']*3 + ['B']*3,
    'value': [1, np.nan, 3, np.nan, 4, np.nan]
})

# 按照group排序
df = df.sort_values(by='group')

# 利用groupby和apply來進行前值填補
df['value_filled'] = df.groupby('group')['value'].apply(lambda x: x.fillna(method='ffill'))

print(df)
# Out:
#   group  value  value_filled
# 0     A    1.0           1.0
# 1     A    NaN           1.0
# 2     A    3.0           3.0
# 3     B    NaN           NaN
# 4     B    4.0           4.0
# 5     B    NaN           4.0
# C:\Users\2022011702\AppData\Local\Temp\ipykernel_24016\2252226661.py:11: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df['value_filled'] = df.groupby('group')['value'].apply(lambda x: x.fillna(method='ffill'))

# %% [markdown]
# ## 測試新流程:
# - 把 tickers 迴圈移除: tickers 直接傳入 tejapi.get.coid
# - 將 triggers-> transfer_language_columns模組化，面對長區間資料以一年為單位，分段執行
# - by ticker 進行填補的方式改為 groupby tickers sort by date apply x.fillna(method='ffill')

# %%
tickers=['2330', '2881', '2882']

data_org = tejapi.get('TWN/AFESTM1',
                    coid=tickers,
                    paginate=True,
                    chinese_column_name=False,
                    mdate={'gte': para.default_start, 'lte': para.default_end},
                    opts={'sort':{'coid.desc', 'mdate.desc'}})
data_org
# Out:
#       coid      mdate key3   no sem fin_type curr       annd fin_ind  \
# None
# 0     2882 2023-03-01    A  001   1        Y  TWD 2023-04-12       O
# 1     2882 2023-03-01    Q  001   1        Y  TWD 2023-04-12       O
# 2     2882 2023-03-01  TTM  001   1        Y  TWD 2023-04-12       O
# 3     2882 2022-12-01    A  001   4        Y  TWD 2023-01-10       O
# 4     2882 2022-12-01    Q  001   4        Y  TWD 2023-01-10       O
# ...    ...        ...  ...  ...  ..      ...  ...        ...     ...
# 952   2330 2013-03-01    Q  001   1        Y  TWD 2013-04-10       F
# 953   2330 2013-03-01  TTM  001   1        Y  TWD 2013-04-10       F
# 954   2330 2013-03-01    A  002   1        Y  TWD 2013-04-18       F
# 955   2330 2013-03-01    Q  002   1        Y  TWD 2013-04-18       F
# 956   2330 2013-03-01  TTM  002   1        Y  TWD 2013-04-18       F
#
#              ip12  ...   eps  r105   r106   r107   r108   r401  r402   r403  \
# None               ...
# 0      68290086.0  ...  0.46   NaN    NaN  10.08  10.07 -48.30   NaN    NaN
# 1      68290086.0  ...   NaN   NaN    NaN  10.08  10.07 -48.35   NaN    NaN
# 2     277646862.0  ...   NaN   NaN    NaN   6.13   3.77 -51.16   NaN    NaN
# 3     342250450.0  ...  2.58   NaN    NaN  14.61  11.11 -45.32   NaN    NaN
# 4      35759731.0  ...   NaN   NaN    NaN -58.29 -46.06 -75.90   NaN    NaN
# ...           ...  ...   ...   ...    ...    ...    ...    ...   ...    ...
# 952   132755000.0  ...   NaN   NaN    NaN    NaN    NaN  25.82   NaN    NaN
# 953   533495905.0  ...   NaN   NaN    NaN    NaN    NaN  24.88   NaN    NaN
# 954   132760000.0  ...  1.53   NaN  33.46  34.46    NaN  25.83   NaN  25.37
# 955   132754996.0  ...  1.53   NaN  33.47  34.46    NaN  25.82   NaN    NaN
# 956   533500905.0  ...  6.64   NaN  35.62  35.92    NaN  24.88   NaN  37.88
#
#         r404    r405
# None
# 0     -82.70  -79.99
# 1     -82.70  -79.99
# 2     -87.43  -91.11
# 3     -68.66  -73.02
# 4    -197.18 -188.93
# ...      ...     ...
# 952      NaN     NaN
# 953      NaN     NaN
# 954    28.31     NaN
# 955      NaN     NaN
# 956    36.42     NaN
#
# [957 rows x 26 columns]

# %%
# select certain fin_type
data_sets = para.dask_mpf.get_certain_fin_type(data_org, ['A','Q','TTM'])
data_sets
# Out:
#       coid      mdate key3   no sem fin_type curr       annd fin_ind  \
# None
# 0     2882 2023-03-01    A  001   1        Y  TWD 2023-04-12       O
# 1     2882 2023-03-01    Q  001   1        Y  TWD 2023-04-12       O
# 2     2882 2023-03-01  TTM  001   1        Y  TWD 2023-04-12       O
# 3     2882 2022-12-01    A  001   4        Y  TWD 2023-01-10       O
# 4     2882 2022-12-01    Q  001   4        Y  TWD 2023-01-10       O
# ...    ...        ...  ...  ...  ..      ...  ...        ...     ...
# 952   2330 2013-03-01    Q  001   1        Y  TWD 2013-04-10       F
# 953   2330 2013-03-01  TTM  001   1        Y  TWD 2013-04-10       F
# 954   2330 2013-03-01    A  002   1        Y  TWD 2013-04-18       F
# 955   2330 2013-03-01    Q  002   1        Y  TWD 2013-04-18       F
# 956   2330 2013-03-01  TTM  002   1        Y  TWD 2013-04-18       F
#
#              ip12  ...   eps  r105   r106   r107   r108   r401  r402   r403  \
# None               ...
# 0      68290086.0  ...  0.46   NaN    NaN  10.08  10.07 -48.30   NaN    NaN
# 1      68290086.0  ...   NaN   NaN    NaN  10.08  10.07 -48.35   NaN    NaN
# 2     277646862.0  ...   NaN   NaN    NaN   6.13   3.77 -51.16   NaN    NaN
# 3     342250450.0  ...  2.58   NaN    NaN  14.61  11.11 -45.32   NaN    NaN
# 4      35759731.0  ...   NaN   NaN    NaN -58.29 -46.06 -75.90   NaN    NaN
# ...           ...  ...   ...   ...    ...    ...    ...    ...   ...    ...
# 952   132755000.0  ...   NaN   NaN    NaN    NaN    NaN  25.82   NaN    NaN
# 953   533495905.0  ...   NaN   NaN    NaN    NaN    NaN  24.88   NaN    NaN
# 954   132760000.0  ...  1.53   NaN  33.46  34.46    NaN  25.83   NaN  25.37
# 955   132754996.0  ...  1.53   NaN  33.47  34.46    NaN  25.82   NaN    NaN
# 956   533500905.0  ...  6.64   NaN  35.62  35.92    NaN  24.88   NaN  37.88
#
#         r404    r405
# None
# 0     -82.70  -79.99
# 1     -82.70  -79.99
# 2     -87.43  -91.11
# 3     -68.66  -73.02
# 4    -197.18 -188.93
# ...      ...     ...
# 952      NaN     NaN
# 953      NaN     NaN
# 954    28.31     NaN
# 955      NaN     NaN
# 956    36.42     NaN
#
# [957 rows x 26 columns]

# %%
data_sets = para.dask_mpf.fin_pivot(data_sets, remain_keys=['coid', 'mdate', 'no', 'sem', 'annd', 'fin_type', 'curr', 'fin_ind'])
data_sets
# Out:
#      coid      mdate   no sem fin_type curr       annd fin_ind       ip12_A  \
# 0    2882 2023-03-01  001   1        Y  TWD 2023-04-12       O   68290086.0
# 1    2882 2022-12-01  001   4        Y  TWD 2023-01-10       O  342250450.0
# 2    2882 2022-12-01  002   4        Y  TWD 2023-03-09       O  342250450.0
# 3    2882 2022-09-01  001   3        Y  TWD 2022-10-07       O  306610648.0
# 4    2882 2022-09-01  002   3        Y  TWD 2022-10-11       O  306610648.0
# ..    ...        ...  ...  ..      ...  ...        ...     ...          ...
# 314  2330 2013-06-01  001   2        Y  TWD 2013-07-10       F  288641000.0
# 315  2330 2013-06-01  002   2        Y  TWD 2013-07-18       F  288650000.0
# 316  2330 2013-06-01  003   2        Y  TWD 2013-07-19       F  288650000.0
# 317  2330 2013-03-01  001   1        Y  TWD 2013-04-10       F  132755000.0
# 318  2330 2013-03-01  002   1        Y  TWD 2013-04-18       F  132760000.0
#
#      gm_A  ...  eps_TTM  r105_TTM  r106_TTM  r107_TTM  r108_TTM  r401_TTM  \
# 0     NaN  ...      NaN       NaN       NaN      6.13      3.77    -51.16
# 1     NaN  ...      NaN       NaN       NaN     14.61     11.11    -45.32
# 2     NaN  ...     2.77       NaN       NaN     14.61     11.09    -45.32
# 3     NaN  ...      NaN       NaN       NaN     20.22     15.98    -28.16
# 4     NaN  ...      NaN       NaN       NaN     20.22     15.98    -28.16
# ..    ...  ...      ...       ...       ...       ...       ...       ...
# 314   NaN  ...      NaN       NaN       NaN       NaN       NaN     26.21
# 315   NaN  ...     7.03       NaN     35.80     36.65       NaN     26.21
# 316   NaN  ...     7.03       NaN     35.80     36.65       NaN     26.21
# 317   NaN  ...      NaN       NaN       NaN       NaN       NaN     24.88
# 318   NaN  ...     6.64       NaN     35.62     35.92       NaN     24.88
#
#      r402_TTM  r403_TTM  r404_TTM  r405_TTM
# 0         NaN       NaN    -87.43    -91.11
# 1         NaN       NaN    -68.66    -73.02
# 2         NaN       NaN    -68.66    -73.06
# 3         NaN       NaN    -38.01    -45.71
# 4         NaN       NaN    -38.01    -45.71
# ..        ...       ...       ...       ...
# 314       NaN       NaN       NaN       NaN
# 315       NaN     37.01     39.62       NaN
# 316       NaN     37.01     39.62       NaN
# 317       NaN       NaN       NaN       NaN
# 318       NaN     37.88     36.42       NaN
#
# [319 rows x 59 columns]

# %%
data_sets.query('mdate > annd')
# Out:
# Empty DataFrame
# Columns: [coid, mdate, no, sem, fin_type, curr, annd, fin_ind, ip12_A, gm_A, isoi_A, isibt_A, isni_A, isnip_A, r306_A, eps_A, r105_A, r106_A, r107_A, r108_A, r401_A, r402_A, r403_A, r404_A, r405_A, ip12_Q, gm_Q, isoi_Q, isibt_Q, isni_Q, isnip_Q, r306_Q, eps_Q, r105_Q, r106_Q, r107_Q, r108_Q, r401_Q, r402_Q, r403_Q, r404_Q, r405_Q, ip12_TTM, gm_TTM, isoi_TTM, isibt_TTM, isni_TTM, isnip_TTM, r306_TTM, eps_TTM, r105_TTM, r106_TTM, r107_TTM, r108_TTM, r401_TTM, r402_TTM, r403_TTM, r404_TTM, r405_TTM]
# Index: []
#
# [0 rows x 59 columns]

# %%
# transfer fin_ann_date to daily basis
days = para.dask_mpf.generate_multicalendars(tickers)
data_sets = dd.merge(days, data_sets, left_on=['coid','all_dates'], right_on=['coid', 'annd'], how='left')
data_sets
# Out:
# Dask DataFrame Structure:
#                      all_dates    coid           mdate      no     sem fin_type    curr            annd fin_ind   ip12_A     gm_A   isoi_A  isibt_A   isni_A  isnip_A   r306_A    eps_A   r105_A   r106_A   r107_A   r108_A   r401_A   r402_A   r403_A   r404_A   r405_A   ip12_Q     gm_Q   isoi_Q  isibt_Q   isni_Q  isnip_Q   r306_Q    eps_Q   r105_Q   r106_Q   r107_Q   r108_Q   r401_Q   r402_Q   r403_Q   r404_Q   r405_Q ip12_TTM   gm_TTM isoi_TTM isibt_TTM isni_TTM isnip_TTM r306_TTM  eps_TTM r105_TTM r106_TTM r107_TTM r108_TTM r401_TTM r402_TTM r403_TTM r404_TTM r405_TTM
# npartitions=12
#                 datetime64[ns]  object  datetime64[ns]  object  object   object  object  datetime64[ns]  object  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64   float64  float64   float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64
#                            ...     ...             ...     ...     ...      ...     ...             ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...       ...      ...       ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...
# ...                        ...     ...             ...     ...     ...      ...     ...             ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...       ...      ...       ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...
#                            ...     ...             ...     ...     ...      ...     ...             ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...       ...      ...       ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...
#                            ...     ...             ...     ...     ...      ...     ...             ...     ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...       ...      ...       ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...
# Dask Name: merge_chunk, 8 graph layers

# %%
data_sets = data_sets.sort_values(['coid', 'all_dates'])#.query('annd > all_dates')

# %%
data_sets = data_sets.groupby('coid', group_keys=False).apply(para.dask_mpf.fillna_multicolumns, meta = data_sets)

# %%
data_sets.compute().query('annd > all_dates')
# Out:
# Empty DataFrame
# Columns: [all_dates, coid, mdate, no, sem, fin_type, curr, annd, fin_ind, ip12_A, gm_A, isoi_A, isibt_A, isni_A, isnip_A, r306_A, eps_A, r105_A, r106_A, r107_A, r108_A, r401_A, r402_A, r403_A, r404_A, r405_A, ip12_Q, gm_Q, isoi_Q, isibt_Q, isni_Q, isnip_Q, r306_Q, eps_Q, r105_Q, r106_Q, r107_Q, r108_Q, r401_Q, r402_Q, r403_Q, r404_Q, r405_Q, ip12_TTM, gm_TTM, isoi_TTM, isibt_TTM, isni_TTM, isnip_TTM, r306_TTM, eps_TTM, r105_TTM, r106_TTM, r107_TTM, r108_TTM, r401_TTM, r402_TTM, r403_TTM, r404_TTM, r405_TTM]
# Index: []
#
# [0 rows x 60 columns]

# %%
data_sets = data_sets.compute()
data_sets
# Out:
#      all_dates  coid      mdate   no  sem fin_type curr       annd fin_ind  \
# 0   2013-01-01  2330        NaT  NaN  NaN      NaN  NaN        NaT     NaN
# 1   2013-01-02  2330        NaT  NaN  NaN      NaN  NaN        NaT     NaN
# 2   2013-01-03  2330        NaT  NaN  NaN      NaN  NaN        NaT     NaN
# 3   2013-01-04  2330        NaT  NaN  NaN      NaN  NaN        NaT     NaN
# 4   2013-01-05  2330        NaT  NaN  NaN      NaN  NaN        NaT     NaN
# ..         ...   ...        ...  ...  ...      ...  ...        ...     ...
# 938 2023-04-24  2882 2023-03-01  001    1        Y  TWD 2023-04-12       O
# 939 2023-04-25  2882 2023-03-01  001    1        Y  TWD 2023-04-12       O
# 940 2023-04-26  2882 2023-03-01  001    1        Y  TWD 2023-04-12       O
# 941 2023-04-27  2882 2023-03-01  001    1        Y  TWD 2023-04-12       O
# 942 2023-04-28  2882 2023-03-01  001    1        Y  TWD 2023-04-12       O
#
#          ip12_A  ...  eps_TTM  r105_TTM  r106_TTM  r107_TTM  r108_TTM  \
# 0           NaN  ...      NaN       NaN       NaN       NaN       NaN
# 1           NaN  ...      NaN       NaN       NaN       NaN       NaN
# 2           NaN  ...      NaN       NaN       NaN       NaN       NaN
# 3           NaN  ...      NaN       NaN       NaN       NaN       NaN
# 4           NaN  ...      NaN       NaN       NaN       NaN       NaN
# ..          ...  ...      ...       ...       ...       ...       ...
# 938  68290086.0  ...     2.77       NaN       NaN      6.13      3.77
# 939  68290086.0  ...     2.77       NaN       NaN      6.13      3.77
# 940  68290086.0  ...     2.77       NaN       NaN      6.13      3.77
# 941  68290086.0  ...     2.77       NaN       NaN      6.13      3.77
# 942  68290086.0  ...     2.77       NaN       NaN      6.13      3.77
#
#      r401_TTM  r402_TTM  r403_TTM  r404_TTM  r405_TTM
# 0         NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...
# 938    -51.16       NaN       NaN    -87.43    -91.11
# 939    -51.16       NaN       NaN    -87.43    -91.11
# 940    -51.16       NaN       NaN    -87.43    -91.11
# 941    -51.16       NaN       NaN    -87.43    -91.11
# 942    -51.16       NaN       NaN    -87.43    -91.11
#
# [11313 rows x 60 columns]

# %%
tickers=['2330', '2881', '2882']
data = para.dask_mpf.get_fin_data('TWN/AFESTM1', tickers=tickers, columns=['r401', 'r404'])

# %%
data.compute()
# Out:
#      all_dates  coid  r401_A curr   no fin_type fin_ind  sem  r404_A  \
# 0   2013-01-01  2330     NaN  NaN  NaN      NaN     NaN  NaN     NaN
# 1   2013-01-02  2330     NaN  NaN  NaN      NaN     NaN  NaN     NaN
# 2   2013-01-03  2330     NaN  NaN  NaN      NaN     NaN  NaN     NaN
# 3   2013-01-04  2330     NaN  NaN  NaN      NaN     NaN  NaN     NaN
# 4   2013-01-05  2330     NaN  NaN  NaN      NaN     NaN  NaN     NaN
# ..         ...   ...     ...  ...  ...      ...     ...  ...     ...
# 938 2023-04-24  2882   -48.3  TWD  001        Y       O    1   -82.7
# 939 2023-04-25  2882   -48.3  TWD  001        Y       O    1   -82.7
# 940 2023-04-26  2882   -48.3  TWD  001        Y       O    1   -82.7
# 941 2023-04-27  2882   -48.3  TWD  001        Y       O    1   -82.7
# 942 2023-04-28  2882   -48.3  TWD  001        Y       O    1   -82.7
#
#           annd  r401_Q  r404_Q  r401_TTM  r404_TTM
# 0          NaT     NaN     NaN       NaN       NaN
# 1          NaT     NaN     NaN       NaN       NaN
# 2          NaT     NaN     NaN       NaN       NaN
# 3          NaT     NaN     NaN       NaN       NaN
# 4          NaT     NaN     NaN       NaN       NaN
# ..         ...     ...     ...       ...       ...
# 938 2023-04-12  -48.35   -82.7    -51.16    -87.43
# 939 2023-04-12  -48.35   -82.7    -51.16    -87.43
# 940 2023-04-12  -48.35   -82.7    -51.16    -87.43
# 941 2023-04-12  -48.35   -82.7    -51.16    -87.43
# 942 2023-04-12  -48.35   -82.7    -51.16    -87.43
#
# [11313 rows x 14 columns]

# %%
data.compute().query('all_dates < annd')
# Out:
# Empty DataFrame
# Columns: [all_dates, coid, r401_A, curr, no, fin_type, fin_ind, sem, r404_A, annd, r401_Q, r404_Q, r401_TTM, r404_TTM]
# Index: []

# %% [markdown]
# ### test get_fin_auditor

# %%
tickers=['2330', '2881', '2882']
data = para.dask_mpf.get_fin_auditor('TWN/AINVFINQ', tickers=tickers, columns=['r404'])

# %%
data.compute()
# Out:
#       all_dates  coid  r404_A      mdate  sem   no       annd  r404_Q  \
# 0    2015-08-01  2330     NaN        NaT  NaN  NaN        NaT     NaN
# 1    2015-08-02  2330     NaN        NaT  NaN  NaN        NaT     NaN
# 2    2015-08-03  2330     NaN        NaT  NaN  NaN        NaT     NaN
# 3    2015-08-04  2330     NaN        NaT  NaN  NaN        NaT     NaN
# 4    2015-08-05  2330     NaN        NaT  NaN  NaN        NaT     NaN
# ...         ...   ...     ...        ...  ...  ...        ...     ...
# 1014 2020-09-23  2882   -4.82 2020-06-01    2  001 2020-08-25  -52.44
# 1015 2020-09-24  2882   -4.82 2020-06-01    2  001 2020-08-25  -52.44
# 1016 2020-09-25  2882   -4.82 2020-06-01    2  001 2020-08-25  -52.44
# 1017 2020-09-26  2882   -4.82 2020-06-01    2  001 2020-08-25  -52.44
# 1018 2020-09-27  2882   -4.82 2020-06-01    2  001 2020-08-25  -52.44
#
#       r404_TTM
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 1014       NaN
# 1015       NaN
# 1016       NaN
# 1017       NaN
# 1018       NaN
#
# [12134 rows x 9 columns]
